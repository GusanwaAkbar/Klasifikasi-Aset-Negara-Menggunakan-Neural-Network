# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow import feature_column
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
# Out:
# 2023-04-06 15:45:55.612041: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-04-06 15:45:55.612098: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
dataframe = pd.read_csv("train csv 2 - skripsi csv 2.csv.csv")

train, test = train_test_split(dataframe, test_size=0.2)
val = pd.read_csv("val csv - Sheet1.csv")

# %%
# importing necessary libraries
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
  
# loading the iris dataset
df_train = pd.read_csv("train csv 2 - skripsi csv 2.csv.csv")
df_test = pd.read_csv("val csv - Sheet1.csv")

target = ["Dimanfaatakan Untuk"]
feature = ["Luas","Jarak pusat kota"]

X_train = df_train[feature]
X_test = df_test[feature]
y_train = df_train[target]
y_test = df_test[target]

    

  
# training a KNN classifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 2).fit(X_train, y_train)
  
# accuracy on X_test
accuracy = knn.score(X_test, y_test)
print (accuracy)
  
# creating a confusion matrix
knn_predictions = knn.predict(X_test) 
cm = confusion_matrix(y_test, knn_predictions)
# Out:
# 0.29411764705882354
# /home/gusanwa/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
knn_predictions
# Out:
# array(['Ruko', 'Kantor', 'Ruko', 'Ruko', 'Pasar', 'Pasar', 'Kantor',
#        'Pasar', 'Sawah', 'Kantor', 'Kantor', 'Kantor', 'Kantor', 'Kantor',
#        'Sawah', 'Pasar', 'Sawah'], dtype=object)

# %%
X_test
# Out:
#      Luas  Jarak pusat kota
# 0    2716              2031
# 1    6025               648
# 2     260              1192
# 3     200              2451
# 4    5784              2222
# 5    5872              2084
# 6    1735              1088
# 7    5055              2265
# 8    7165              1946
# 9     270              1658
# 10   1217              1128
# 11    335              1782
# 12    500              1762
# 13   1945               978
# 14  18110              2615
# 15  13155              2251
# 16   6065              2225

# %%
y_test
# Out:
#    Dimanfaatakan Untuk
# 0               Kantor
# 1               Kantor
# 2               Kantor
# 3               Kantor
# 4                Pasar
# 5                Pasar
# 6                Pasar
# 7            Perumahan
# 8            Perumahan
# 9                 Ruko
# 10                Ruko
# 11                Ruko
# 12                Ruko
# 13               Taman
# 14               Sawah
# 15               Sawah
# 16               Sawah

# %%
df_train
# Out:
#       No Bentuk Pemanfaatan Dimanfaatakan Untuk          Desa   Kecamatan  \
# 0   40.0               Sewa                Ruko           NaN         NaN
# 1   38.0               Sewa                Ruko           NaN         NaN
# 2   60.0               Sewa               Sawah           NaN         NaN
# 3   28.0               Sewa           Perumahan         KELUN  KARTOHARJO
# 4   89.0              Pakai               Sawah       JOSENAN       TAMAN
# ..   ...                ...                 ...           ...         ...
# 80  39.0               Sewa                Ruko           NaN         NaN
# 81  11.0               Sewa               Pasar       KEJURON       TAMAN
# 82   8.0               Sewa                Mall    KARTOHARJO  KARTOHARJO
# 83  15.0              Pakai               Pasar  PANGONGANGAN  MANGUHARJO
# 84  33.0               Sewa                Ruko       PANDEAN       TAMAN
#
#    Jenis Hak                               Jalan            Pengelola   Luas  \
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 4).fit(X_train, y_train)
dtree_predictions = dtree_model.predict(X_test)
  
# creating a confusion matrix
cm = confusion_matrix(y_test, dtree_predictions)

cm
# Out:
# array([[9, 2],
#        [4, 2]])

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(X_train, y_train)
gnb_predictions = gnb.predict(X_test)
  
# accuracy on X_test
accuracy = gnb.score(X_test, y_test)
print (accuracy)
  
# creating a confusion matrix
cm = confusion_matrix(y_test, gnb_predictions)
cm
# Out:
# 0.6470588235294118
# /home/gusanwa/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([[11,  0],
#        [ 6,  0]])
